# %%
import pandas as pd
import seaborn as sns
import user_agents
from ip2geotools.databases.noncommercial import DbIpCity as ip2geo

# %% [markdown]
# ## Using visitor-interests.csv dataset, from the first 50 row extract Browser, OS, Device data from 'UserAgent' column and use it to create new columns for Browser, OS, Device

# %%
visitor_interests = pd.read_csv("visitor-interests.csv")
visitor_interests
# Out:
#                    IP                                          UserAgent  \
# 0        1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...
# 1         1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2       1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...
# 3       1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...
# 4       1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...
# ...               ...                                                ...
# 19921      223.62.3.2  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...
# 19922   223.62.67.192  Mozilla/5.0 (Linux; Android 6.0.1; SM-N920S Bu...
# 19923   223.73.243.82  Mozilla/5.0 (Linux; U; Android 5.1.1; zh-cn; v...
# 19924    223.73.66.65  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...
# 19925  223.81.193.148  Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.3...
#
#       Country Languages                     Interests
# ...

# %%
visitor_interests = visitor_interests.loc[:50]
visitor_interests
# Out:
#                IP                                          UserAgent Country  \
# 0    1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...      TH
# 1     1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...      TH
# 2   1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...      JP
# 3   1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...      AU
# 4   1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...      AU
# 5    1.124.48.210  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU
# 6     1.124.48.99  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU
# 7    1.126.48.118  Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7....      AU
# 8    1.126.48.171  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...      AU
# 9     1.126.48.47  Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_4 like ...      AU
# 10   1.128.96.235  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...      AU
# ...

# %%
def extracting_Browser_OS_Device(UA):
    UA = user_agents.parse(UA)
    return pd.Series((UA.os.family , UA.browser.family , UA.device.family))
visitor_interests[["OS" , "Browser" , "Device"]] = visitor_interests["UserAgent"].apply(extracting_Browser_OS_Device)
visitor_interests
# Out:
#                IP                                          UserAgent Country  \
# 0    1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...      TH
# 1     1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...      TH
# 2   1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...      JP
# 3   1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...      AU
# 4   1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...      AU
# 5    1.124.48.210  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU
# 6     1.124.48.99  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU
# 7    1.126.48.118  Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7....      AU
# 8    1.126.48.171  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...      AU
# 9     1.126.48.47  Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_4 like ...      AU
# 10   1.128.96.235  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...      AU
# ...

# %%
visitor_interests["OS"].value_counts()
# Out:
# Android     19
# Windows     15
# iOS         14
# Mac OS X     2
# Ubuntu       1
# Name: OS, dtype: int64

# %%
sns.countplot(data = visitor_interests , x = "OS")
# Out:
# <AxesSubplot:xlabel='OS', ylabel='count'>

# %%
visitor_interests["Browser"].value_counts()
# Out:
# Mobile Safari       13
# Chrome              12
# Samsung Internet     6
# Chrome Mobile        6
# Firefox              4
# UC Browser           3
# Android              2
# Google               1
# MiuiBrowser          1
# Dragon               1
# Chromium             1
# IE                   1
# Name: Browser, dtype: int64

# %%
sns.countplot(data = visitor_interests , y = "Browser")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Browser'>

# %%
visitor_interests["Device"].value_counts()
# Out:
# Other                  16
# iPhone                 11
# iPad                    3
# Samsung SM-G900I        3
# Mac                     2
# vivo Y15S               1
# Samsung GT-S7262        1
# XT1022                  1
# Samsung SM-G800Y        1
# Samsung SM-N910G        1
# Samsung SM-T355Y        1
# Samsung SM-J500F        1
# Nexus 9                 1
# Samsung SM-N915G        1
# A550s IPS               1
# Lenovo A6010            1
# XiaoMi Redmi Note 3     1
# Samsung SM-T315         1
# Asus T00I               1
# Lenovo A7000-a          1
# Samsung SM-N920I        1
# Name: Device, dtype: int64

# %%
sns.countplot(data = visitor_interests , y = "Device")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Device'>

# %% [markdown]
# ## Using visitor-interests.csv dataset, from the first 50 row extract latitude, longitude from 'IP' column.

# %%
def extract_lat_long(ip):
    try:
        response = ip2geo.get(ip, api_key='free')
        return pd.Series((response.latitude , response.longitude))
    except:
        return np.NaN
    
visitor_interests[['latitude' , 'longitude']] = visitor_interests['IP'].apply(extract_lat_long)
visitor_interests
# Out:
#                IP                                          UserAgent Country  \
# 0    1.10.195.126  Mozilla/5.0 (Windows NT 6.1; Win64; x64) Apple...      TH
# 1     1.1.217.211  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...      TH
# 2   1.115.198.107  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.3...      JP
# 3   1.121.152.143  Mozilla/5.0 (Linux; Android 7.0; Nexus 9 Build...      AU
# 4   1.123.135.213  Mozilla/5.0 (iPad; CPU OS 9_3_5 like Mac OS X)...      AU
# 5    1.124.48.210  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU
# 6     1.124.48.99  Mozilla/5.0 (Linux; Android 5.0; SAMSUNG SM-G9...      AU
# 7    1.126.48.118  Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7....      AU
# 8    1.126.48.171  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.11; ...      AU
# 9     1.126.48.47  Mozilla/5.0 (iPhone; CPU iPhone OS 7_0_4 like ...      AU
# 10   1.128.96.235  Mozilla/5.0 (Linux; Android 6.0.1; SAMSUNG SM-...      AU
# ...
